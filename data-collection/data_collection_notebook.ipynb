# %% [markdown]
# # Data Collection Notebook
#
# This notebook version of `data_collection.py` keeps the same dataset-generation logic while splitting it into smaller sections that are easier to inspect, modify, and run incrementally.
#
# It includes:
#
# - PyTorch Geometric `.pt` export
# - episode-level train/val/test splits
# - tapered temporal sampling
# - rollout metadata per graph
# - a JSON sidecar describing the dataset recipe

# %%
import json
import os
from typing import Literal

import numpy as np
import pybullet as p
import torch
from scipy.optimize import linear_sum_assignment
from torch_geometric.data import Data, HeteroData, InMemoryDataset

from PyFlyt.core import Aviary

# %% [markdown]
# ## Global Constants
#
# This cell defines formation labels and split-specific seed offsets. The split offsets make validation and test episodes use different random streams from training even when you start from one base seed.

# %%
FORMATION_NAMES = ("a", "rectangle", "triangle")
FORMATION_TO_ID = {name: idx for idx, name in enumerate(FORMATION_NAMES)}
SPLIT_NAMES = ("train", "val", "test")
SPLIT_SEED_OFFSETS = {"train": 0, "val": 1_000_000, "test": 2_000_000}
TASK_TYPES = ("setpoint_prediction", "residual_correction", "formation_assignment_homo", "formation_assignment_hetero")

# %% [markdown]
# ## Wind and Episode Initialization
#
# These helpers generate a simple wind field and sample randomized initial conditions for each episode. The initialization function accepts a NumPy random generator so each episode can be reproduced from a seed.

# %%
def wind_generator(time: float, position: np.ndarray):
    """Generates an upward draft with random turbulence."""
    wind = np.zeros_like(position)
    wind[:, 2] = np.sin(time) * 0.5 + np.random.normal(0, 0.2, size=(len(position),))
    wind[:, 0] = np.cos(time / 2.0) * 0.3
    wind[:, 1] = np.sin(time / 2.0) * 0.3
    return wind


def sample_episode_initial_conditions(
    num_drones: int,
    rng: np.random.Generator,
    xy_limit: float = 10.0,
    altitude_range: tuple[float, float] = (0.5, 5.0),
):
    start_pos = rng.uniform(-xy_limit, xy_limit, size=(num_drones, 3))
    start_pos[:, 2] = rng.uniform(altitude_range[0], altitude_range[1], size=(num_drones,))

    start_orn = np.zeros((num_drones, 3))
    start_orn[:, 2] = rng.uniform(-np.pi, np.pi, size=(num_drones,))
    return start_pos, start_orn

def sample_obstacles(rng: np.random.Generator, num_obstacles: int, xy_limit: float):
    """Generate random non-overlapping vertical obstacles (cylinders)."""
    if num_obstacles == 0:
        return np.zeros((0, 2))
    return rng.uniform(-xy_limit, xy_limit, size=(num_obstacles, 2))

def resolve_formation_name(dataset_type: str):
    if dataset_type in {"a", "formation_a"}:
        return "a"
    if dataset_type in {"rectangle", "rectangular", "formation_rectangle"}:
        return "rectangle"
    if dataset_type in {"triangle", "formation_triangle"}:
        return "triangle"
    return None

# %% [markdown]
# ## Formation Geometry
#
# These helpers define how each formation is laid out in the XY plane. The setpoints are centered around the episode's mean initial position so the swarm moves into formation without teleporting the target far away from the sampled scenario.

# %%
def _formation_a_offsets(num_drones: int, spacing: float = 2.0):
    offsets = np.zeros((num_drones, 3))
    if num_drones == 1:
        return offsets
    offsets[0] = np.array([0.0, 0.0, 0.0])
    for idx in range(1, num_drones):
        level = (idx + 1) // 2
        side = -1.0 if idx % 2 == 1 else 1.0 
        offsets[idx, 0] = side * level * spacing 
        offsets[idx, 1] = level * spacing

    offsets[:, :2] -= np.mean(offsets[:, :2], axis=0) 
    return offsets


def _formation_rectangle_offsets(num_drones: int, spacing: float = 2.0):
    cols = int(np.ceil(np.sqrt(num_drones)))
    rows = int(np.ceil(num_drones / cols))

    offsets = np.zeros((num_drones, 3))
    for idx in range(num_drones):
        row = idx // cols
        col = idx % cols
        offsets[idx, 0] = (col - (cols - 1) / 2.0) * spacing
        offsets[idx, 1] = (row - (rows - 1) / 2.0) * spacing

    return offsets


def _formation_triangle_offsets(num_drones: int, spacing: float = 2.0):
    offsets = np.zeros((num_drones, 3))

    count = 0
    row = 0
    while count < num_drones:
        points_in_row = row + 1
        row_y = row * spacing
        row_start_x = -0.5 * row * spacing

        for col in range(points_in_row):
            if count >= num_drones:
                break
            offsets[count, 0] = row_start_x + col * spacing
            offsets[count, 1] = row_y
            count += 1

        row += 1

    offsets[:, :2] -= np.mean(offsets[:, :2], axis=0)
    return offsets


def apply_obstacle_avoidance(slots, obstacles, obstacle_radius, padding=1.0):
    """Pushes format slots out of obstacles if they overlap."""
    if len(obstacles) == 0:
        return slots
    
    safe_slots = np.copy(slots)
    min_dist = obstacle_radius + padding
    
    for i in range(len(safe_slots)):
        for obs in obstacles:
            diff = safe_slots[i, :2] - obs
            dist = np.linalg.norm(diff)
            if dist < min_dist:
                direction = diff / (dist + 1e-6)
                safe_slots[i, :2] = obs + direction * min_dist
                
    return safe_slots


def _build_formation_setpoints(formation_name: str, start_pos: np.ndarray, obstacles=np.empty((0, 2)), obstacle_radius=0.0):
    num_drones = len(start_pos)
    formation_center = np.mean(start_pos[:, :2], axis=0)
    target_altitude = np.mean(start_pos[:, 2])

    if formation_name == "a":
        offsets = _formation_a_offsets(num_drones)
    elif formation_name == "rectangle":
        offsets = _formation_rectangle_offsets(num_drones)
    elif formation_name == "triangle":
        offsets = _formation_triangle_offsets(num_drones)
    else:
        return None, None, None

    # Step 1: Base slots (naive)
    global_slots = np.zeros((num_drones, 3))
    global_slots[:, :2] = formation_center + offsets[:, :2]
    
    # Step 2: Apply obstacle avoidance to shift slots dynamically
    safe_global_slots = apply_obstacle_avoidance(global_slots, obstacles, obstacle_radius, padding=1.0)
    
    # Step 3: Optimal Assignment
    dist_matrix = np.linalg.norm(start_pos[:, None, :2] - safe_global_slots[None, :, :2], axis=2)
    _, assigned_indices = linear_sum_assignment(dist_matrix)
    
    # Step 4: Build final setpoints
    setpoints = np.zeros((num_drones, 4))
    for i in range(num_drones):
        slot_idx = assigned_indices[i]
        setpoints[i, :2] = safe_global_slots[slot_idx, :2]
        setpoints[i, 2] = 0.0 # Yaw
        setpoints[i, 3] = target_altitude

    return setpoints, assigned_indices, offsets

# %% [markdown]
# ## Environment Creation and Setpoint Generation
#
# This part creates the PyFlyt `Aviary`, enables optional wind, and generates setpoints for either a formation task or a generic random-hovering style task.

# %%
def create_aviary(
    start_pos: np.ndarray,
    start_orn: np.ndarray,
    environmental_wind: bool,
    obstacles: np.ndarray = np.empty((0,2)),
    obstacle_radius: float = 1.0,
    graphical: bool = False,
):
    env = Aviary(
        start_pos=start_pos,
        start_orn=start_orn,
        drone_type="quadx",
        render=graphical,
    )

    if environmental_wind:
        env.register_wind_field_function(wind_generator)

    env.set_mode(7)

    # Spawn simple cylinder obstacles if present
    if len(obstacles) > 0:
        physics_client = env._client
        for obs in obstacles:
            # Add simple stationary cylinders in pybullet
            col_id = p.createCollisionShape(p.GEOM_CYLINDER, radius=obstacle_radius, height=10.0, physicsClientId=physics_client)
            vis_id = p.createVisualShape(p.GEOM_CYLINDER, radius=obstacle_radius, length=10.0, rgbaColor=[1,0,0,0.5], physicsClientId=physics_client)
            p.createMultiBody(baseMass=0, baseCollisionShapeIndex=col_id, baseVisualShapeIndex=vis_id, basePosition=[obs[0], obs[1], 5.0], physicsClientId=physics_client)
        env.register_all_new_bodies()

    return env


def build_setpoints(
    dataset_type: str,
    start_pos: np.ndarray,
    start_orn: np.ndarray,
    rng: np.random.Generator,
    obstacles: np.ndarray = np.empty((0,2)),
    obstacle_radius: float = 1.0,
):
    num_drones = len(start_pos)
    formation_name = resolve_formation_name(dataset_type)
    
    if formation_name is not None:
        setpoints, col_ind, offsets = _build_formation_setpoints(formation_name, start_pos, obstacles, obstacle_radius)
        if setpoints is not None:
            return setpoints, col_ind, offsets

    # Default fallback (hovering or aggressive target changing)
    setpoints = np.zeros((num_drones, 4))
    if dataset_type == "hovering":
        setpoints[:, :2] = start_pos[:, :2]
        setpoints[:, 2] = start_orn[:, 2]
        setpoints[:, 3] = start_pos[:, 2]
    else:
        radius = 10.0 if dataset_type == "aggressive" else 5.0
        setpoints[:, :2] = start_pos[:, :2] + rng.uniform(-radius, radius, size=(num_drones, 2))
        setpoints[:, 2] = rng.uniform(-np.pi, np.pi, size=(num_drones,))
        setpoints[:, 3] = rng.uniform(1.0, radius, size=(num_drones,))

    col_ind = np.arange(num_drones)
    return setpoints, col_ind, np.zeros((num_drones, 3))

# %% [markdown]
# ## State Processing and Graph Construction
#
# These helpers transform raw drone state into graph node features, target vectors, and communication edges. This is the part that turns the simulator rollout into supervised learning samples for the GNN.

# %%
def maybe_add_sensor_noise(
    global_pos: np.ndarray,
    global_euler: np.ndarray,
    local_lin_vel: np.ndarray,
    local_ang_vel: np.ndarray,
    noisy_sensors: bool,
    noise_variance: float,
):
    if not noisy_sensors:
        return global_pos, global_euler, local_lin_vel, local_ang_vel

    global_pos = global_pos + np.random.normal(0, noise_variance, size=3)
    global_euler = global_euler + np.random.normal(0, noise_variance, size=3)
    local_lin_vel = local_lin_vel + np.random.normal(0, noise_variance, size=3)
    local_ang_vel = local_ang_vel + np.random.normal(0, noise_variance, size=3)
    return global_pos, global_euler, local_lin_vel, local_ang_vel


def build_drone_features(
    drone,
    drone_idx: int,
    setpoint: np.ndarray,
    assigned_slot_idx: int,
    naive_offset: np.ndarray,
    task_type: str,
    noisy_sensors: bool,
    noise_variance: float,
    formation_one_hot: np.ndarray | None,
    obstacles: np.ndarray,
    include_formation_in_state: bool,
    start_pos_center: np.ndarray,
):
    state = drone.state
    global_pos = np.array(state[3], copy=True)
    global_euler = np.array(state[1], copy=True)
    local_lin_vel = np.array(state[2], copy=True)
    local_ang_vel = np.array(state[0], copy=True)

    global_pos, global_euler, local_lin_vel, local_ang_vel = maybe_add_sensor_noise(
        global_pos,
        global_euler,
        local_lin_vel,
        local_ang_vel,
        noisy_sensors,
        noise_variance,
    )

    # Inject visible obstacles into state (relative x, y of nearest 2 obstacles)
    obs_features = np.zeros(4)
    if len(obstacles) > 0:
        rel_obs = obstacles - global_pos[:2]
        dists = np.linalg.norm(rel_obs, axis=1)
        closest_idxs = np.argsort(dists)[:2]
        for i, idx in enumerate(closest_idxs):
            obs_features[i*2:(i+1)*2] = rel_obs[idx]

    gnn_input_state = np.concatenate([local_lin_vel, local_ang_vel, obs_features])
    if include_formation_in_state and formation_one_hot is not None:
        gnn_input_state = np.concatenate([gnn_input_state, formation_one_hot])

    target_global_pos = np.array([setpoint[0], setpoint[1], setpoint[3]])
    target_global_yaw = setpoint[2]

    # Target switch logic
    if task_type == "setpoint_prediction":
        global_pos_error = target_global_pos - global_pos
        yaw_error = target_global_yaw - global_euler[2]
        yaw_error = (yaw_error + np.pi) % (2 * np.pi) - np.pi
        
        rotation_quaternion = p.getQuaternionFromEuler(global_euler)
        rot_matrix = np.array(p.getMatrixFromQuaternion(rotation_quaternion)).reshape(3, 3)
        local_pos_error = rot_matrix.T @ global_pos_error
        y_label = np.concatenate([local_pos_error, [yaw_error]])

    elif task_type == "residual_correction":
        naive_global_pos = np.array([
            start_pos_center[0] + naive_offset[0],
            start_pos_center[1] + naive_offset[1],
            target_global_pos[2]
        ])
        y_label = target_global_pos - naive_global_pos

    elif task_type in ("formation_assignment_homo", "formation_assignment_hetero"):
        y_label = np.array([assigned_slot_idx], dtype=np.float32)

    gnn_input_target = y_label
    motor_pwm_labels = drone.pwm

    return gnn_input_state, gnn_input_target, motor_pwm_labels, global_pos


def build_edges(global_positions: np.ndarray, communication_radius: float):
    edges = []
    edge_attrs = []
    num_drones = len(global_positions)

    for i in range(num_drones):
        for j in range(num_drones):
            if i == j:
                continue

            rel_pos = global_positions[j] - global_positions[i]
            dist = np.linalg.norm(rel_pos)
            if dist <= communication_radius:
                edges.append([i, j])
                edge_attrs.append(rel_pos)

    return edges, edge_attrs


def collect_step_data(
    env,
    active_drones: list[int],
    setpoints,
    slot_assignments: list[int],
    naive_offsets: np.ndarray,
    task_type: str,
    noisy_sensors: bool,
    noise_variance: float,
    communication_radius: float,
    formation_one_hot: np.ndarray | None,
    obstacles: np.ndarray,
    include_formation_in_state: bool,
    start_pos_center: np.ndarray,
):
    episode_states = []
    episode_targets = []
    episode_labels = []
    global_positions = []

    for i, drone_idx in enumerate(active_drones):
        drone = env.drones[drone_idx]
        slot_idx = slot_assignments[i]
        gnn_input_state, gnn_input_target, motor_pwm_labels, global_pos = build_drone_features(
            drone,
            drone_idx,
            setpoints[i],
            slot_idx,
            naive_offsets[slot_idx],
            task_type,
            noisy_sensors,
            noise_variance,
            formation_one_hot,
            obstacles,
            include_formation_in_state,
            start_pos_center,
        )
        episode_states.append(gnn_input_state)
        # Note: in residual/assignement targets, episode targets is the y_label.
        episode_targets.append(gnn_input_target)
        episode_labels.append(motor_pwm_labels)
        global_positions.append(global_pos)

    edges, edge_attrs = build_edges(np.array(global_positions), communication_radius)
    return episode_states, episode_targets, episode_labels, edges, edge_attrs

# %% [markdown]
# ## Split Logic, Tapered Sampling, and Metadata
#
# This section implements the practical dataset design choices discussed earlier:
#
# - split by episode rather than by graph
# - use separate seed streams for train, val, and test
# - optionally save more steps early and fewer later
# - write a metadata sidecar so the dataset recipe is reproducible

# %%
def compute_split_episode_counts(
    num_episodes: int,
    split_ratios: tuple[float, float, float],
):
    if len(split_ratios) != 3:
        raise ValueError("split_ratios must contain exactly three values for train, val, test.")
    if not np.isclose(sum(split_ratios), 1.0):
        raise ValueError("split_ratios must sum to 1.0.")

    counts = [int(num_episodes * ratio) for ratio in split_ratios]
    remainder = num_episodes - sum(counts)
    for idx in range(remainder):
        counts[idx] += 1

    return {split_name: count for split_name, count in zip(SPLIT_NAMES, counts)}


def resolve_split_spread_scale(
    split_name: str,
    validation_spread_scale: float,
    test_spread_scale: float,
):
    if split_name == "val":
        return validation_spread_scale
    if split_name == "test":
        return test_spread_scale
    return 1.0


def should_sample_step(
    step_idx: int,
    max_steps: int,
    tapered_sampling: bool,
    dense_sampling_steps: int,
    mid_sampling_steps: int,
    mid_step_stride: int,
    late_step_stride: int,
):
    if not tapered_sampling or step_idx == max_steps - 1:
        return True

    mid_sampling_steps = max(mid_sampling_steps, dense_sampling_steps)

    if step_idx < dense_sampling_steps:
        return True
    if step_idx < mid_sampling_steps:
        return (step_idx - dense_sampling_steps) % mid_step_stride == 0
    return (step_idx - mid_sampling_steps) % late_step_stride == 0


def build_episode_seed(seed: int | None, split_name: str, split_episode_idx: int):
    if seed is None:
        return None
    return int(seed + SPLIT_SEED_OFFSETS[split_name] + split_episode_idx)


def write_dataset_metadata(metadata_path: str, metadata: dict):
    with open(metadata_path, "w", encoding="ascii") as metadata_file:
        json.dump(metadata, metadata_file, indent=2)
        metadata_file.write("\n")


def save_dataset(
    dataset_path: str,
    all_graphs,
    formation_names,
    split_name: str,
):
    data, slices = InMemoryDataset.collate(all_graphs)
    torch.save(
        {
            "data": data,
            "slices": slices,
            "formation_names": formation_names,
            "split_name": split_name,
        },
        dataset_path,
    )

# %% [markdown]
# ## Main Dataset Generator
#
# This is the full generation loop. It creates split-specific episodes, applies the tapered sampling policy, stores one PyG graph per retained step, and writes both split files and a metadata JSON file.

# %%
def generate_dataset(
    num_episodes: int = 200,
    max_steps: int = 300,
    dataset_name: str = "formation_dataset",
    dataset_type: str = "mixed_formations",
    task_type: Literal[
        "setpoint_prediction", 
        "residual_correction", 
        "formation_assignment_homo", 
        "formation_assignment_hetero"
    ] = "setpoint_prediction",
    num_obstacles: int = 0,
    obstacle_radius: float = 1.0,
    inject_failures: bool = False,
    dynamic_formation: bool = False,
    noisy_sensors: bool = False,
    noise_variance: float = 0.01,
    environmental_wind: bool = False,
    graphical: bool = False,
    communication_radius: float = np.inf,
    include_formation_in_state: bool = True,
    mixed_formation_types: tuple = FORMATION_NAMES,
    split_ratios: tuple[float, float, float] = (0.8, 0.1, 0.1),
    seed: int = 12345,
    base_xy_limit: float = 10.0,
    altitude_range: tuple[float, float] = (0.5, 5.0),
    validation_spread_scale: float = 1.25,
    test_spread_scale: float = 1.5,
    tapered_sampling: bool = True,
    dense_sampling_steps: int = 120,
    mid_sampling_steps: int = 240,
    mid_step_stride: int = 2,
    late_step_stride: int = 5,
) -> tuple[dict[str, str], str]:
    if '__file__' in globals():
        script_dir = os.path.dirname(os.path.abspath(__file__))
    else:
        script_dir = os.path.abspath(os.getcwd())
    repo_root = os.path.dirname(script_dir)
    datasets_dir = os.path.join(repo_root, "datasets")
    os.makedirs(datasets_dir, exist_ok=True)

    if task_type not in TASK_TYPES:
        raise ValueError(f"task_type must be one of {TASK_TYPES}")

    dataset_prefix = os.path.join(datasets_dir, f"{dataset_name}_{dataset_type}")
    split_episode_counts = compute_split_episode_counts(num_episodes, split_ratios)
    split_graphs = {split_name: [] for split_name in SPLIT_NAMES}
    split_summaries = {}
    episode_records = []

    global_episode_id = 0
    for split_name in SPLIT_NAMES:
        split_episode_count = split_episode_counts[split_name]
        split_spread_scale = resolve_split_spread_scale(
            split_name,
            validation_spread_scale,
            test_spread_scale,
        )
        split_summaries[split_name] = {
            "num_episodes": split_episode_count,
            "num_graphs": 0,
            "spread_scale": split_spread_scale,
        }

        for split_episode_idx in range(split_episode_count):
            episode_seed = build_episode_seed(seed, split_name, split_episode_idx)
            rng = np.random.default_rng(episode_seed)

            print(
                f"[{dataset_name}] Starting {split_name} episode {split_episode_idx + 1}/{split_episode_count} ..."
            )

            num_drones = int(rng.integers(10, 21))
            episode_dataset_type = dataset_type
            if dataset_type in {"mixed_formations", "mixed", "formations"}:
                episode_dataset_type = str(rng.choice(mixed_formation_types))

            xy_limit = base_xy_limit * split_spread_scale
            start_pos, start_orn = sample_episode_initial_conditions(
                num_drones, rng, xy_limit=xy_limit, altitude_range=altitude_range
            )
            obstacles = sample_obstacles(rng, num_obstacles, xy_limit=5.0)
            
            env = create_aviary(start_pos, start_orn, environmental_wind, obstacles, obstacle_radius, graphical)
            setpoints, col_ind, naive_offsets = build_setpoints(episode_dataset_type, start_pos, start_orn, rng, obstacles, obstacle_radius)
            active_drones = list(range(num_drones))
            
            formation_name = resolve_formation_name(episode_dataset_type)
            formation_id = -1
            if formation_name is not None:
                formation_id = FORMATION_TO_ID[formation_name]

            formation_one_hot = None
            if formation_id >= 0:
                formation_one_hot = np.zeros(len(FORMATION_NAMES), dtype=np.float32)
                formation_one_hot[formation_id] = 1.0

            # Only setting it for active drones
            for i, drone_idx in enumerate(active_drones):
                env.set_setpoint(drone_idx, setpoints[i])

            saved_steps = 0
            for step_idx in range(max_steps):
                # Optionally inject mid-flight failure
                if inject_failures and step_idx == max_steps // 2 and len(active_drones) > 2:
                    failed_drone = active_drones.pop() # logically drop a drone
                    env.drones[failed_drone].set_mode(0) # kill motors physically
                    # Recalculate setpoints with N-1 drones
                    active_start_pos = np.array([env.drones[idx].state[3] for idx in active_drones])
                    setpoints, col_ind, naive_offsets = build_setpoints(episode_dataset_type, active_start_pos, start_orn[:len(active_drones)], rng, obstacles, obstacle_radius)
                    for i, drone_idx in enumerate(active_drones):
                        env.drones[drone_idx].set_mode(7)
                        env.set_setpoint(drone_idx, setpoints[i])

                # Optionally rotate formation dynamically
                if dynamic_formation and step_idx > 0 and step_idx % 100 == 0:
                    next_shape = str(rng.choice(tuple(set(FORMATION_NAMES) - {formation_name})))
                    formation_name = next_shape
                    formation_id = FORMATION_TO_ID[formation_name]
                    formation_one_hot = np.zeros(len(FORMATION_NAMES), dtype=np.float32)
                    formation_one_hot[formation_id] = 1.0
                    active_start_pos = np.array([env.drones[idx].state[3] for idx in active_drones])
                    setpoints, col_ind, naive_offsets = build_setpoints(formation_name, active_start_pos, start_orn[:len(active_drones)], rng, obstacles, obstacle_radius)
                    for i, drone_idx in enumerate(active_drones):
                        env.set_setpoint(drone_idx, setpoints[i])
                        
                if should_sample_step(
                    step_idx, max_steps, tapered_sampling, dense_sampling_steps,
                    mid_sampling_steps, mid_step_stride, late_step_stride
                ):
                    episode_states, episode_targets, episode_labels, edges, edge_attrs = collect_step_data(
                        env, active_drones, setpoints, col_ind, naive_offsets, task_type,
                        noisy_sensors, noise_variance, communication_radius, formation_one_hot,
                        obstacles, include_formation_in_state, np.mean(start_pos[:, :2], axis=0)
                    )

                    x = torch.as_tensor(np.asarray(episode_states), dtype=torch.float32)
                    target = torch.as_tensor(np.asarray(episode_targets), dtype=torch.float32)
                    y = torch.as_tensor(np.asarray(episode_labels), dtype=torch.float32)

                    if edges:
                        edge_index = torch.tensor(edges, dtype=torch.long).t().contiguous()
                        edge_attr = torch.tensor(edge_attrs, dtype=torch.float32)
                    else:
                        edge_index = torch.empty((2, 0), dtype=torch.long)
                        edge_attr = torch.empty((0, 3), dtype=torch.float32)

                    if task_type == "formation_assignment_hetero":
                        graph = HeteroData()
                        graph["drone"].x = x
                        graph["drone"].y = y
                        graph["slot"].x = torch.as_tensor(naive_offsets, dtype=torch.float32)
                        graph["drone", "communicates", "drone"].edge_index = edge_index
                        graph["drone", "communicates", "drone"].edge_attr = edge_attr
                        
                        drones = torch.arange(len(active_drones), dtype=torch.long)
                        slots = target.view(-1).long()
                        graph["drone", "assigned_to", "slot"].edge_label_index = torch.stack([drones, slots], dim=0)

                        graph.formation_id = torch.tensor([formation_id], dtype=torch.long)
                        graph.episode_id = torch.tensor([global_episode_id], dtype=torch.long)
                        graph.step_idx = torch.tensor([step_idx], dtype=torch.long)
                        graph.num_drones = torch.tensor([len(active_drones)], dtype=torch.long)
                    else:
                        graph = Data(
                            x=x, target=target, y=y, edge_index=edge_index, edge_attr=edge_attr,
                            formation_id=torch.tensor([formation_id], dtype=torch.long),
                            episode_id=torch.tensor([global_episode_id], dtype=torch.long),
                            step_idx=torch.tensor([step_idx], dtype=torch.long),
                            num_drones=torch.tensor([len(active_drones)], dtype=torch.long),
                        )
                    split_graphs[split_name].append(graph)
                    saved_steps += 1

                env.step()

            env.disconnect()

            split_summaries[split_name]["num_graphs"] += saved_steps
            episode_center = np.mean(start_pos[:, :2], axis=0)
            initial_xy_radius = float(np.max(np.linalg.norm(start_pos[:, :2] - episode_center, axis=1)))
            episode_records.append({
                "episode_id": global_episode_id, "split": split_name,
                "split_episode_idx": split_episode_idx, "episode_seed": episode_seed,
                "num_drones": num_drones, "episode_dataset_type": episode_dataset_type,
                "formation_name": formation_name, "initial_xy_limit": xy_limit,
                "initial_xy_radius": initial_xy_radius, "saved_steps": saved_steps,
            })
            global_episode_id += 1

    generated_files = {}
    for split_name, graphs in split_graphs.items():
        if not graphs: continue
        split_dataset_path = f"{dataset_prefix}_{split_name}.pt"
        save_dataset(split_dataset_path, graphs, FORMATION_NAMES, split_name)
        generated_files[split_name] = os.path.basename(split_dataset_path)
        print(f"Generated {split_name} dataset -> {split_dataset_path}")

    metadata_path = f"{dataset_prefix}_metadata.json"
    metadata = {
        "dataset_name": dataset_name, "dataset_type": dataset_type, "task_type": task_type,
        "config": {
            "num_episodes": num_episodes, "max_steps": max_steps, "num_obstacles": num_obstacles,
            "obstacle_radius": obstacle_radius, "inject_failures": inject_failures,
            "dynamic_formation": dynamic_formation, "noisy_sensors": noisy_sensors,"noise_variance": noise_variance,
            "environmental_wind": environmental_wind,"graphical": graphical,"communication_radius": communication_radius,
            "include_formation_in_state": include_formation_in_state,"mixed_formation_types": list(mixed_formation_types),
            "split_ratios": list(split_ratios),"seed": seed,"base_xy_limit": base_xy_limit,
            "altitude_range": list(altitude_range),"validation_spread_scale": validation_spread_scale,
            "test_spread_scale": test_spread_scale,"tapered_sampling": tapered_sampling,
            "dense_sampling_steps": dense_sampling_steps,"mid_sampling_steps": mid_sampling_steps,
            "mid_step_stride": mid_step_stride,"late_step_stride": late_step_stride,
        },
        "split_summary": split_summaries, "episodes": episode_records,
    }
    write_dataset_metadata(metadata_path, metadata)
    print(f"Generated dataset metadata -> {metadata_path}")

    return generated_files, metadata_path

# %% [markdown]
# ## Example Usage
#
# The final cell shows a practical default configuration. Leave it commented if you only want the notebook as documentation, or run it to generate split `.pt` files and the metadata JSON.

# %%
# Example generation call
generated_files, metadata_path =  generate_dataset(
     dataset_name="noiseless_baseline",
     task_type="formation_assignment_homo",
     noisy_sensors=False,
     environmental_wind=False,
     dynamic_formation=False,
     inject_failures=False,
     num_episodes=500  # Good size for baseline
)
print(generated_files)
print(metadata_path)
# Out:
# [noiseless_baseline] Starting train episode 1/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 2/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 3/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 4/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 5/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 6/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 7/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 8/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 9/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 10/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 11/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 12/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 13/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 14/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 15/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 16/400 ...
#                              argv[0]=
#
# [noiseless_baseline] Starting train episode 17/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 18/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 19/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 20/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 21/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 22/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 23/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 24/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 25/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 26/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 27/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 28/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 29/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 30/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 31/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 32/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 33/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 34/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 35/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 36/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 37/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 38/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 39/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 40/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 41/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 42/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 43/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 44/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 45/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 46/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 47/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 48/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 49/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 50/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 51/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 52/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 53/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 54/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 55/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 56/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 57/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 58/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 59/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 60/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 61/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 62/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 63/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 64/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 65/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 66/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 67/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 68/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 69/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 70/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 71/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 72/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 73/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 74/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 75/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 76/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 77/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 78/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 79/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 80/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 81/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 82/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 83/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 84/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 85/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 86/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 87/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 88/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 89/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 90/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 91/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 92/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 93/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 94/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 95/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 96/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 97/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 98/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 99/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 100/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 101/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 102/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 103/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 104/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 105/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 106/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 107/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 108/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 109/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 110/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 111/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 112/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 113/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 114/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 115/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 116/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 117/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 118/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 119/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 120/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 121/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 122/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 123/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 124/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 125/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 126/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 127/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 128/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 129/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 130/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 131/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 132/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 133/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 134/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 135/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 136/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 137/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 138/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 139/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 140/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 141/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 142/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 143/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 144/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 145/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 146/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 147/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 148/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 149/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 150/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 151/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 152/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 153/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 154/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 155/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 156/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 157/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 158/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 159/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 160/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 161/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 162/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 163/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 164/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 165/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 166/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 167/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 168/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 169/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 170/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 171/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 172/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 173/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 174/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 175/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 176/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 177/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 178/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 179/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 180/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 181/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 182/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 183/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 184/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 185/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 186/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 187/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 188/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 189/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 190/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 191/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 192/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 193/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 194/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 195/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 196/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 197/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 198/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 199/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 200/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 201/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 202/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 203/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 204/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 205/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 206/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 207/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 208/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 209/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 210/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 211/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 212/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 213/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 214/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 215/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 216/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 217/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 218/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 219/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 220/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 221/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 222/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 223/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 224/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 225/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 226/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 227/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 228/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 229/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 230/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 231/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 232/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 233/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 234/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 235/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 236/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 237/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 238/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 239/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 240/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 241/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 242/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 243/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 244/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 245/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 246/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 247/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 248/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 249/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 250/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 251/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 252/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 253/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 254/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 255/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 256/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 257/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 258/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 259/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 260/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 261/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 262/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 263/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 264/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 265/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 266/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 267/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 268/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 269/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 270/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 271/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 272/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 273/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 274/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 275/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 276/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 277/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 278/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 279/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 280/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 281/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 282/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 283/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 284/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 285/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 286/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 287/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 288/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 289/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 290/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 291/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 292/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 293/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 294/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 295/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 296/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 297/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 298/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 299/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 300/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 301/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 302/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 303/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 304/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 305/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 306/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 307/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 308/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 309/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 310/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 311/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 312/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 313/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 314/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 315/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 316/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 317/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 318/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 319/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 320/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 321/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 322/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 323/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 324/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 325/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 326/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 327/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 328/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 329/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 330/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 331/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 332/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 333/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 334/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 335/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 336/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 337/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 338/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 339/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 340/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 341/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 342/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 343/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 344/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 345/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 346/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 347/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 348/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 349/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 350/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 351/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 352/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 353/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 354/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 355/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 356/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 357/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 358/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 359/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 360/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 361/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 362/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 363/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 364/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 365/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 366/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 367/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 368/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 369/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 370/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 371/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 372/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 373/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 374/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 375/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 376/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 377/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 378/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 379/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 380/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 381/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 382/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 383/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 384/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 385/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 386/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 387/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 388/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 389/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 390/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 391/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 392/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 393/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 394/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 395/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 396/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting train episode 397/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 398/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 399/400 ...
#
# argv[0]=
# [noiseless_baseline] Starting train episode 400/400 ...
# argv[0]=
#
# [noiseless_baseline] Starting val episode 1/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting val episode 2/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting val episode 3/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting val episode 4/50 ...
# argv[0]=
#
# [noiseless_baseline] Starting val episode 5/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting val episode 6/50 ...
# argv[0]=
#
# [noiseless_baseline] Starting val episode 7/50 ...
# argv[0]=
#
# [noiseless_baseline] Starting val episode 8/50 ...
# argv[0]=
#
# [noiseless_baseline] Starting val episode 9/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting val episode 10/50 ...
# argv[0]=
#
# [noiseless_baseline] Starting val episode 11/50 ...
# argv[0]=
#
# [noiseless_baseline] Starting val episode 12/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting val episode 13/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting val episode 14/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting val episode 15/50 ...
# argv[0]=
#
# [noiseless_baseline] Starting val episode 16/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting val episode 17/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting val episode 18/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting val episode 19/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting val episode 20/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting val episode 21/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting val episode 22/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting val episode 23/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting val episode 24/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting val episode 25/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting val episode 26/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting val episode 27/50 ...
# argv[0]=
#
# [noiseless_baseline] Starting val episode 28/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting val episode 29/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting val episode 30/50 ...
# argv[0]=
#
# [noiseless_baseline] Starting val episode 31/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting val episode 32/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting val episode 33/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting val episode 34/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting val episode 35/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting val episode 36/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting val episode 37/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting val episode 38/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting val episode 39/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting val episode 40/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting val episode 41/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting val episode 42/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting val episode 43/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting val episode 44/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting val episode 45/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting val episode 46/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting val episode 47/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting val episode 48/50 ...
# argv[0]=
#
# [noiseless_baseline] Starting val episode 49/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting val episode 50/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting test episode 1/50 ...
# argv[0]=
#
# [noiseless_baseline] Starting test episode 2/50 ...
# argv[0]=
#
# [noiseless_baseline] Starting test episode 3/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting test episode 4/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting test episode 5/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting test episode 6/50 ...
# argv[0]=
#
# [noiseless_baseline] Starting test episode 7/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting test episode 8/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting test episode 9/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting test episode 10/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting test episode 11/50 ...
# argv[0]=
#
# [noiseless_baseline] Starting test episode 12/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting test episode 13/50 ...
# argv[0]=
#
# [noiseless_baseline] Starting test episode 14/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting test episode 15/50 ...
# argv[0]=
#
# [noiseless_baseline] Starting test episode 16/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting test episode 17/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting test episode 18/50 ...
# argv[0]=
#
# [noiseless_baseline] Starting test episode 19/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting test episode 20/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting test episode 21/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting test episode 22/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting test episode 23/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting test episode 24/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting test episode 25/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting test episode 26/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting test episode 27/50 ...
# argv[0]=
#
# [noiseless_baseline] Starting test episode 28/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting test episode 29/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting test episode 30/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting test episode 31/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting test episode 32/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting test episode 33/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting test episode 34/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting test episode 35/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting test episode 36/50 ...
# argv[0]=
#
# [noiseless_baseline] Starting test episode 37/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting test episode 38/50 ...
# argv[0]=
#
# [noiseless_baseline] Starting test episode 39/50 ...
# argv[0]=
#
# [noiseless_baseline] Starting test episode 40/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting test episode 41/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting test episode 42/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting test episode 43/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting test episode 44/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting test episode 45/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting test episode 46/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting test episode 47/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting test episode 48/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting test episode 49/50 ...
#
# argv[0]=
# [noiseless_baseline] Starting test episode 50/50 ...
#
# argv[0]=
# Generated train dataset -> /home/amirbnsl/projects/gnn_drone_project/datasets/noiseless_baseline_mixed_formations_train.pt
# Generated val dataset -> /home/amirbnsl/projects/gnn_drone_project/datasets/noiseless_baseline_mixed_formations_val.pt
# Generated test dataset -> /home/amirbnsl/projects/gnn_drone_project/datasets/noiseless_baseline_mixed_formations_test.pt
# Generated dataset metadata -> /home/amirbnsl/projects/gnn_drone_project/datasets/noiseless_baseline_mixed_formations_metadata.json
# {'train': 'noiseless_baseline_mixed_formations_train.pt', 'val': 'noiseless_baseline_mixed_formations_val.pt', 'test': 'noiseless_baseline_mixed_formations_test.pt'}
# /home/amirbnsl/projects/gnn_drone_project/datasets/noiseless_baseline_mixed_formations_metadata.json

# %% [markdown]
# ## Inspect a Generated Split
#
# This section uses a small PyTorch Geometric `InMemoryDataset` wrapper to load one generated split exactly the way a PyG training pipeline would. It reconstructs the dataset, inspects one sample graph, and then shows how PyG batches graphs with a `DataLoader`.

# %%
from pathlib import Path



from torch_geometric.loader import DataLoader





class GeneratedSplitDataset(InMemoryDataset):

    def __init__(self, split_path: str | Path):

        self.split_path = Path(split_path)

        payload = torch.load(self.split_path, weights_only=False)

        self.formation_names = payload.get("formation_names", [])

        self.split_name = payload.get("split_name", "unknown")

        super().__init__(root="")

        self.data = payload["data"]

        self.slices = payload["slices"]





inspect_dataset_name = "noiseless_baseline_mixed_formations"

inspect_split_name = "train"



notebook_dir = Path.cwd()

datasets_dir = notebook_dir.parent / "datasets"



split_path = datasets_dir / f"{inspect_dataset_name}_{inspect_split_name}.pt"

metadata_path = datasets_dir / f"{inspect_dataset_name}_metadata.json"



if not split_path.exists():

    raise FileNotFoundError(

        f"Could not find split dataset at {split_path}. Generate the dataset first or update inspect_dataset_name."

    )



dataset = GeneratedSplitDataset(split_path)



print(f"Loaded split file: {split_path.name}")

print(f"Stored split name: {dataset.split_name}")

print(f"Available formation names: {dataset.formation_names}")

print(f"Number of graphs: {len(dataset)}")



sample_graph = dataset[0]

print("\nSample graph summary:")

print(sample_graph)

print(f"x shape: {tuple(sample_graph.x.shape)}")

print(f"target shape: {tuple(sample_graph.target.shape)}")

print(f"y shape: {tuple(sample_graph.y.shape)}")
print(f"edge_index shape: {tuple(sample_graph.edge_index.shape)}")
if hasattr(sample_graph, 'edge_attr') and sample_graph.edge_attr is not None:
    print(f"edge_attr shape: {tuple(sample_graph.edge_attr.shape)}")
print(f"episode_id: {int(sample_graph.episode_id.item())}")

print(f"step_idx: {int(sample_graph.step_idx.item())}")

print(f"num_drones: {int(sample_graph.num_drones.item())}")

print(f"formation_id: {int(sample_graph.formation_id.item())}")



loader = DataLoader(dataset, batch_size=4, shuffle=False)

batch = next(iter(loader))

print("\nPyG batch summary:")

print(batch)

print(f"batched x shape: {tuple(batch.x.shape)}")

print(f"batched edge_index shape: {tuple(batch.edge_index.shape)}")

print(f"batch vector shape: {tuple(batch.batch.shape)}")

print(f"graphs in batch: {batch.num_graphs}")



if metadata_path.exists():

    with open(metadata_path, "r", encoding="ascii") as metadata_file:

        metadata = json.load(metadata_file)



    print("\nMetadata summary:")

    print(f"Metadata file: {metadata_path.name}")

    print(f"Configured dataset type: {metadata['dataset_type']}")

    print(f"Configured split files: {metadata['generated_files']}")

    print(f"Split summary: {metadata['split_summary'][inspect_split_name]}")

    print(f"First episode record: {metadata['episodes'][0]}")

else:

    print(f"\nNo metadata file found at {metadata_path}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 53
#      47 metadata_path = datasets_dir / f"{inspect_dataset_name}_metadata.json"
#      51 if not split_path.exists():
# ---> 53     raise FileNotFoundError(
#      54
#      55         f"Could not find split dataset at {split_path}. Generate the dataset first or update inspect_dataset_name."
#      56
#      57     )
#      61 dataset = GeneratedSplitDataset(split_path)
#      65 print(f"Loaded split file: {split_path.name}")
#
# FileNotFoundError: Could not find split dataset at /home/amirbnsl/projects/gnn_drone_project/datasets/noiseless_baseline_mixed_formations_train.pt. Generate the dataset first or update inspect_dataset_name.

# %% [markdown]
# ## Upload a Dataset to Google Drive
#
# This section is intended for Google Colab. It mounts Google Drive and copies the generated split files and metadata JSON into `MyDrive/dataset/<dataset-name>/`. Update the dataset name if you want to upload a different generated dataset bundle.

# %%
import shutil

from pathlib import Path



upload_dataset_name = "formation_mixed_comm_10m_mixed_formations"

google_drive_root = Path("/content/drive/MyDrive")

google_drive_dataset_dir = google_drive_root / "dataset" / upload_dataset_name



try:

    from google.colab import drive

except ImportError as exc:

    raise RuntimeError(

        "This upload cell is intended to run in Google Colab, where google.colab is available."

    ) from exc



drive.mount("/content/drive", force_remount=False)



local_datasets_dir = Path.cwd().parent / "datasets"

google_drive_dataset_dir.mkdir(parents=True, exist_ok=True)



artifacts_to_copy = sorted(local_datasets_dir.glob(f"{upload_dataset_name}*.pt"))

metadata_file = local_datasets_dir / f"{upload_dataset_name}_metadata.json"

if metadata_file.exists():

    artifacts_to_copy.append(metadata_file)



if not artifacts_to_copy:

    raise FileNotFoundError(

        f"No dataset artifacts found for {upload_dataset_name} in {local_datasets_dir}."

    )



copied_files = []

for artifact_path in artifacts_to_copy:

    destination_path = google_drive_dataset_dir / artifact_path.name

    shutil.copy2(artifact_path, destination_path)

    copied_files.append(destination_path)



print(f"Uploaded {len(copied_files)} files to {google_drive_dataset_dir}")

for copied_file in copied_files:

    print(f" - {copied_file.name}")
