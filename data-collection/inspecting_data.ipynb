# %%
import numpy as np
import pandas as pd

dataset = np.load("/home/amirbnsl/projects/PyFlyt/datasets/clean_comm_10m_random.npz", allow_pickle=True)
print(dataset.files)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 import numpy as np
#       2 import pandas as pd
# ----> 4 dataset = np.load("/home/amirbnsl/projects/PyFlyt/datasets/clean_comm_10m_random.npz", allow_pickle=True)
#       5 print(dataset.files)
#
# File c:\Users\aimen\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\_npyio_impl.py:454, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     452     own_fid = False
#     453 else:
# --> 454     fid = stack.enter_context(open(os.fspath(file), "rb"))
#     455     own_fid = True
#     457 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/amirbnsl/projects/PyFlyt/datasets/clean_comm_10m_random.npz'

# %%
states = dataset["states"]
actions = dataset["targets"]
labels = dataset["labels"]
edges = dataset["edges"]
df = pd.DataFrame({
    "states": states,
    "actions": actions,
    "labels": labels,
    "edges": edges
})
df_length = len(df)
print(f"Dataset length: {df_length}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 states = dataset["states"]
#       2 actions = dataset["targets"]
#       3 labels = dataset["labels"]
#
# NameError: name 'dataset' is not defined
